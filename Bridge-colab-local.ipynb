# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('C:/Users/Admin/Desktop/obj_dog/test_images/image2.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img=np.array(img)

# %%
from flask import Flask
import requests
import json
img_array=json.dumps(img.tolist())

# %%
app=Flask(__name__)
response=requests.post('http://b48e7957.ngrok.io/getImage',json={'Img':img_array})

# %%
img_json=response.json()

# %%
img_json=np.array(img_json)

# %%
plt.imshow(img_json)
